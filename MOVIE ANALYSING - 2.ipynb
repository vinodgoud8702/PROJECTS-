# %%
#libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# loading data set
data = pd.read_csv(r"C:\Users\rvg59\python project data\IMDb_Dataset_2.csv")

# %%
#to check data loaded or we can use info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3173 entries, 0 to 3172
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               3173 non-null   object
#  1   IMDb Rating         3173 non-null   float64
#  2   Year                3173 non-null   int64
#  3   Certificates        3173 non-null   object
#  4   Genre               3173 non-null   object
#  5   Director            3173 non-null   object
#  6   Star Cast           3173 non-null   object
#  7   MetaScore           3173 non-null   float64
#  8   Poster-src          3173 non-null   object
#  9   Duration (minutes)  3173 non-null   float64
# dtypes: float64(3), int64(1), object(6)
# memory usage: 248.0+ KB

# %%
data.isnull()
# Out:
#       Title  IMDb Rating   Year  Certificates  Genre  Director  Star Cast  \
# 0     False        False  False         False  False     False      False
# 1     False        False  False         False  False     False      False
# 2     False        False  False         False  False     False      False
# 3     False        False  False         False  False     False      False
# 4     False        False  False         False  False     False      False
# ...     ...          ...    ...           ...    ...       ...        ...
# 3168  False        False  False         False  False     False      False
# 3169  False        False  False         False  False     False      False
# 3170  False        False  False         False  False     False      False
# 3171  False        False  False         False  False     False      False
# 3172  False        False  False         False  False     False      False
#
#       MetaScore  Poster-src  Duration (minutes)
# ...

# %%
data.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Poster-src            0
# Duration (minutes)    0
# dtype: int64

# %%
data.head(10)
# Out:
#                           Title  IMDb Rating  Year Certificates        Genre  \
# 0              End of the Spear          6.8  2005        PG-13    Adventure
# 1                Elvira Madigan          7.0  1967           PG    Biography
# 2  The Kid Stays in the Picture          7.3  2002            R  Documentary
# 3                 It Ain't Over          8.2  2022           PG  Documentary
# 4                        Mahler          7.0  1974           PG    Biography
# 5                The Dark Horse          7.4  2014            R    Biography
# 6     Stephen Curry: Underrated          7.3  2023        PG-13  Documentary
# 7                    Carrington          6.8  1995            R    Biography
# 8                        Burden          6.7  2018            R    Biography
# 9                    Georgetown          6.2  2019            R    Biography
#
#                  Director                                         Star Cast  \
# ...

# %%
data.tail(10)
# Out:
#                                                   Title  IMDb Rating  Year  \
# 3163                                          12th Fail          8.9  2023
# 3164  The Lord of the Rings: The Fellowship of the Ring          8.9  2001
# 3165                                       Pulp Fiction          8.9  1994
# 3166                              The Godfather Part II          9.0  1974
# 3167                                       12 Angry Men          9.0  1957
# 3168      The Lord of the Rings: The Return of the King          9.0  2003
# 3169                                   Schindler's List          9.0  1993
# 3170                                    The Dark Knight          9.0  2008
# 3171                                      The Godfather          9.2  1972
# 3172                           The Shawshank Redemption          9.3  1994
#
#      Certificates      Genre              Director  \
# 3163            R  Biography    Vidhu Vinod Chopra
# ...

# %%
data.describe()
# Out:
#        IMDb Rating         Year    MetaScore  Duration (minutes)
# count  3173.000000  3173.000000  3173.000000         3173.000000
# mean      6.931012  2004.958399    65.993066          116.304822
# std       0.805202    16.819985    11.358619           22.123032
# min       3.900000  1917.000000    20.000000           46.000000
# 25%       6.400000  1997.000000    64.000000          105.000000
# 50%       6.900000  2010.000000    66.000000          116.300000
# 75%       7.500000  2017.000000    69.000000          122.000000
# max       9.500000  2025.000000   100.000000          317.000000

# %%
data["Year"].value_counts()
# Out:
# Year
# 2018    147
# 2015    142
# 2016    133
# 2023    130
# 2014    129
#        ...
# 1924      1
# 1933      1
# 1937      1
# 1938      1
# 1931      1
# Name: count, Length: 93, dtype: int64

# %%
data["Year"].value_counts(2018)
# Out:
# Year
# 2018    0.046328
# 2015    0.044753
# 2016    0.041916
# 2023    0.040971
# 2014    0.040656
#           ...
# 1924    0.000315
# 1933    0.000315
# 1937    0.000315
# 1938    0.000315
# 1931    0.000315
# Name: proportion, Length: 93, dtype: float64

# %%
data["Certificates"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       PG-13
# 1          PG
# 2           R
# 3          PG
# 4          PG
#         ...
# 3168    PG-13
# 3169        R
# 3170    PG-13
# 3171        R
# 3172        R
# Name: Certificates, Length: 3173, dtype: object>

# %%
data["Director"].value_counts()
# Out:
# Director
# Ridley Scott          23
# Steven Spielberg      19
# Martin Scorsese       14
# Clint Eastwood        12
# Oliver Stone          12
#                       ..
# Julian Cole            1
# Riku Niemelä           1
# James Ian Mair         1
# Jeremy Dean            1
# Vidhu Vinod Chopra     1
# Name: count, Length: 2089, dtype: int64

# %%
data["Star Cast"].value_counts()
# Out:
# Star Cast
# Daniel RadcliffeEmma WatsonRupert Grint            146
# J.R.R. TolkienFran WalshPhilippa Boyens              7
# Hayao Miyazaki                                       6
# Byron HowardRich MooreJared Bush                     5
# Samara WeavingAdam BrodyMark O'Brien                 5
#                                                   ...
# Oleg YankovskiyPyotr MamonovTatyana Lyutaeva         1
# Bernard FressonClaude RichAndréa Ferréol             1
# Alan MooreStewart LeeJosie Long                      1
# Eric Paul ChapmanMaureen O'MalleyTerry McNavage      1
# Tim RobbinsMorgan FreemanBob Gunton                  1
# Name: count, Length: 2592, dtype: int64

# %%
data.shape
# Out:
# (3173, 10)

# %%
data.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Poster-src', 'Duration (minutes)'],
#       dtype='object')

# %%
data[data.index==3170]
# Out:
#                 Title  IMDb Rating  Year Certificates   Genre  \
# 3170  The Dark Knight          9.0  2008        PG-13  Action
#
#                Director                                      Star Cast  \
# 3170  Christopher Nolan  Jonathan NolanChristopher NolanDavid S. Goyer
#
#       MetaScore                                         Poster-src  \
# 3170       84.0  https://m.media-amazon.com/images/M/MV5BMTMxNT...
#
#       Duration (minutes)
# 3170               152.0

# %%
data[data.index.isin(range(10,15))]
# Out:
#                                       Title  IMDb Rating  Year Certificates  \
# 10                              Miles Ahead          6.4  2015            R
# 11  The King of Kong: A Fistful of Quarters          8.0  2007        PG-13
# 12                    The Devil's Violinist          6.0  2013            R
# 13              A Tale of Love and Darkness          6.0  2015        PG-13
# 14                                     Cobb          6.4  1994            R
#
#           Genre         Director  \
# 10    Biography      Don Cheadle
# 11  Documentary      Seth Gordon
# 12    Biography     Bernard Rose
# 13    Biography  Natalie Portman
# 14    Biography      Ron Shelton
#
#                                        Star Cast  MetaScore  \
# 10  Steven BaigelmanDon CheadleStephen J. Rivele       64.0
# 11         Steve WiebeBilly MitchellMark Alpiger       83.0
# 12     David GarrettJared HarrisJoely Richardson       38.0
# ...

# %%
data.iloc[300:310]
# Out:
#                             Title  IMDb Rating  Year Certificates      Genre  \
# 300                   Topsy-Turvy          7.3  1999            R  Biography
# 301  The Greatest Story Ever Told          6.6  1965            G  Biography
# 302         The Old Man & the Gun          6.7  2018        PG-13  Biography
# 303                Antwone Fisher          7.3  2002        PG-13  Biography
# 304                        Kinsey          7.1  2004            R  Biography
# 305               The Current War          6.5  2017        PG-13  Biography
# 306            Million Dollar Arm          7.0  2014           PG  Biography
# 307                Pawn Sacrifice          7.0  2014        PG-13  Biography
# 308          24 Hour Party People          7.3  2002            R  Biography
# 309              Victoria & Abdul          6.8  2017        PG-13  Biography
#
#                  Director                                          Star Cast  \
# ...

# %%
data.sort_values(by=["Director"],ascending = True)
# Out:
#                                           Title  IMDb Rating  Year  \
# 2274                          The Better Angels          6.0  2014
# 1725               The Diamonds of Metro Valley          7.2  2010
# 1090                The Super Mario Bros. Movie          7.0  2023
# 1339                        Standards of Living          6.7  2012
# 1798                                 Pioneer 12          5.9  1999
# ...                                         ...          ...   ...
# 2197                        The Black Pimpernel          6.2  2007
# 2253                                O Jerusalem          6.0  2006
# 2332                          The Marquise of O          7.0  1976
# 2258                      The Lady and the Duke          6.8  2001
# 1775  Katuwira, donde nacen y mueren los sueños          5.5  1996
#
#      Certificates      Genre              Director  \
# 2274           PG  Biography          A.J. Edwards
# 1725            R     Action          Aaron Arendt
# ...

# %%
data.sort_values(by=["MetaScore"],ascending = False)
# Out:
#                                Title  IMDb Rating  Year Certificates  \
# 694               Lawrence of Arabia          8.3  1962           PG
# 3123                     Rear Window          8.5  1954           PG
# 3122                      Casablanca          8.5  1942           PG
# 3171                   The Godfather          9.2  1972            R
# 3078              Lawrence of Arabia          8.3  1962           PG
# ...                              ...          ...   ...          ...
# 74                        Modigliani          7.2  2004            R
# 2008               Maximum Overdrive          5.4  1986            R
# 2336                  One Man's Hero          6.0  1999            R
# 1999  Hansel & Gretel: Witch Hunters          6.1  2013            R
# 785                         Joe Dirt          6.0  2001        PG-13
#
#           Genre              Director  \
# 694   Adventure            David Lean
# 3123    Mystery      Alfred Hitchcock
# ...

# %%
data[["Title", "Year"]].head()
# Out:
#                           Title  Year
# 0              End of the Spear  2005
# 1                Elvira Madigan  1967
# 2  The Kid Stays in the Picture  2002
# 3                 It Ain't Over  2022
# 4                        Mahler  1974

# %%
data[["Title", "Year"]].tail()
# Out:
#                                               Title  Year
# 3168  The Lord of the Rings: The Return of the King  2003
# 3169                               Schindler's List  1993
# 3170                                The Dark Knight  2008
# 3171                                  The Godfather  1972
# 3172                       The Shawshank Redemption  1994

# %%
data["IMDb Rating"].min()
# Out:
# 3.9

# %%
data["IMDb Rating"].max()
# Out:
# 9.5

# %%
data["IMDb Rating"].mean()
# Out:
# 6.931011660888748

# %%
data.shape[0]
# Out:
# 3173

# %%
top_rated = data.sort_values(by='IMDb Rating', ascending=False).head(10)
print("Top Rated Movies:\n", top_rated[['Title', 'IMDb Rating']])
# Out:
# Top Rated Movies:
#                                                Title  IMDb Rating
# 1710                                Marty's Project          9.5
# 2100                             The People's Story          9.5
# 3172                       The Shawshank Redemption          9.3
# 2102                                  Loving Carmen          9.3
# 1344                               Fuga dalla Morte          9.2
# 3171                                  The Godfather          9.2
# 1039  The Lord of the Rings: The Return of the King          9.0
# 1224                  Fast Shark III: Fastest Shark          9.0
# 2916                               Schindler's List          9.0
# 3170                                The Dark Knight          9.0

# %%
#top 10 flop movies using rating
# Top 10 rated movies     #sorting
flop = data.sort_values(by='IMDb Rating', ascending=True).head(10)
print("flop Movies:\n", flop[['Title', 'IMDb Rating']])
# Out:
# flop Movies:
#                                                    Title  IMDb Rating
# 2091                                         Madame Web          3.9
# 885                                             Monster          4.6
# 935                                             Monster          4.6
# 880                                           Imaginary          4.7
# 930                                           Imaginary          4.7
# 2000                                           Anaconda          4.9
# 1241                                   Monismanien 1995          5.0
# 1726                           Double Happiness Uranium          5.0
# 1526  The Other Side of the Lake the Purple Girl: Ep...          5.0
# 1239                  Mocland - A super space adventure          5.0

# %%
numerical_cols = ["IMDb Rating","MetaScore","Duration (minutes)"]
sns.pairplot(data[numerical_cols])
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y='Genre', data=data, order=data['Genre'].value_counts().index)
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['IMDb Rating'], bins=20, kde=True)
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Duration (minutes)'], bins=20, kde=True)

plt.show()

# %%
plt.figure(figsize=(15, 10))
sns.scatterplot(data, x='Year', y='IMDb Rating')
plt.xlabel('Year')
plt.ylabel('IMDb Rating')
# Out:
# Text(0, 0.5, 'IMDb Rating')

# %%
sns.boxplot(data=data, x='Certificates', y='IMDb Rating')
plt.xlabel('Certificates')
plt.ylabel('IMDb Rating')
# Out:
# Text(0, 0.5, 'IMDb Rating')

# %%
data["Poster-src"].value_counts()
# Out:
# Poster-src
# https://m.media-amazon.com/images/M/MV5BOTMyMjEyNzIzMV5BMl5BanBnXkFtZTgwNzIyNjU0NzE@._V1_QL75_UX190_CR0,0,190,281_.jpg                                     144
# https://m.media-amazon.com/images/M/MV5BYzBkMzAyMDUtZTFkZS00OWUyLTgwM2ItNGI3MTQ5NzA3NTVkXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_QL75_UX190_CR0,1,190,281_.jpg       5
# https://m.media-amazon.com/images/M/MV5BMTg0MTU5ODkwM15BMl5BanBnXkFtZTYwMzgxNzY3._V1_QL75_UY281_CR0,0,190,281_.jpg                                           4
# https://m.media-amazon.com/images/M/MV5BYjQ5NjM0Y2YtNjZkNC00ZDhkLWJjMWItN2QyNzFkMDE3ZjAxXkEyXkFqcGdeQXVyODIxMzk5NjA@._V1_QL75_UY281_CR4,0,190,281_.jpg       4
# https://m.media-amazon.com/images/M/MV5BMjMwNDkxMTgzOF5BMl5BanBnXkFtZTgwNTkwNTQ3NjM@._V1_QL75_UX190_CR0,0,190,281_.jpg                                       4
#                                                                                                                                                           ...
# ...

# %%
data = pd.DataFrame({
    'Title': ["End of the Spear", "Elvira Madigan", "The Kid Stays in the Picture"],
    'Year': [2005, 1967, 2002],
    'Poster-src': [
        'https://m.media-amazon.com/images/M/MV5BOTMyMjEyNzIzMV5BMl5BanBnXkFtZTgwNzIyNjU0NzE@._V1_QL75_UX190_CR0,0,190,281_.jpg',
        'https://m.media-amazon.com/images/M/MV5BYzBkMzAyMDUtZTFkZS00OWUyLTgwM2ItNGI3MTQ5NzA3NTVkXkEyXkFqcGdeQXVyMTkxNjUyNQ@@._V1_QL75_UX190_CR0,1,190,281_.jpg',
        'https://m.media-amazon.com/images/M/MV5BYjQ5NjM0Y2YtNjZkNC00ZDhkLWJjMWItN2QyNzFkMDE3ZjAxXkEyXkFqcGdeQXVyODIxMzk5NjA@._V1_QL75_UY281_CR4,0,190,281_.jpg'
    ]
})
print(data)
# Out:
#                           Title  Year  \
# 0              End of the Spear  2005
# 1                Elvira Madigan  1967
# 2  The Kid Stays in the Picture  2002
#
#                                           Poster-src
# 0  https://m.media-amazon.com/images/M/MV5BOTMyMj...
# 1  https://m.media-amazon.com/images/M/MV5BYzBkMz...
# 2  https://m.media-amazon.com/images/M/MV5BYjQ5Nj...
