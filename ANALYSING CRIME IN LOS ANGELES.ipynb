# %% [markdown]
# # Los Angeles Crime Data (2021-2023)

# %%
# libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# loading data 
data = pd.read_csv(r"C:\Users\rvg59\python project data\crime_data.csv")

# %%
#to know is there any null 
data.isnull
# Out:
# <bound method DataFrame.isnull of          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 0       2022-04-12  2020-10-01    00:01    19      Mission         1     821
# 1       2023-01-05  2020-02-01    08:00     2      Rampart         2     812
# 2       2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 3       2023-06-04  2020-07-01    12:00    20      Olympic         2     812
# 4       2022-02-02  2020-02-09    12:00    11    Northeast         2     930
# ...            ...         ...      ...   ...          ...       ...     ...
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
# ...

# %%
#sum of nulls
data.isnull().sum()
# Out:
# Date Rptd       0
# DATE OCC        0
# TIME OCC        0
# AREA            0
# AREA NAME       0
# Part 1-2        0
# Crm Cd          0
# Crm Cd Desc     0
# Vict Age        0
# Vict Sex        0
# Vict Descent    0
# Premis Desc     0
# Weapon Desc     0
# Status Desc     0
# LOCATION        0
# dtype: int64

# %%
#  the first 5 rows of the DataFrame
data.head(5)
# Out:
#     Date Rptd    DATE OCC TIME OCC  AREA  AREA NAME  Part 1-2  Crm Cd  \
# 0  2022-04-12  2020-10-01    00:01    19    Mission         1     821
# 1  2023-01-05  2020-02-01    08:00     2    Rampart         2     812
# 2  2023-03-21  2020-03-15    12:00    19    Mission         2     812
# 3  2023-06-04  2020-07-01    12:00    20    Olympic         2     812
# 4  2022-02-02  2020-02-09    12:00    11  Northeast         2     930
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 0  SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO...         8        F
# 1  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 2  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...        12        F
# 3  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...         7        F
# 4             CRIMINAL THREATS - NO WEAPON DISPLAYED        30        F
#
#   Vict Descent                                   Premis Desc  \
# ...

# %%
#  the last 5 rows of the DataFrame
data.tail(5)
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 230540  2023-08-27  2023-08-27    00:30    15  N Hollywood         1     761
# 230541  2023-07-24  2023-07-24    14:00     6    Hollywood         1     210
# 230542  2023-12-15  2023-12-14    11:05    16     Foothill         1     210
# 230543  2023-07-08  2023-07-08    12:30     1      Central         2     626
# 230544  2023-03-22  2023-03-22    10:00    16     Foothill         1     230
#
#                                            Crm Cd Desc  Vict Age Vict Sex  \
# 230540                                 BRANDISH WEAPON        38        M
# 230541                                         ROBBERY        23        F
# 230542                                         ROBBERY        65        F
# 230543               INTIMATE PARTNER - SIMPLE ASSAULT        35        M
# 230544  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        25        F
#
#        Vict Descent             Premis Desc  \
# ...

# %%
# to get more information about the data set
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 230545 entries, 0 to 230544
# Data columns (total 15 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Date Rptd     230545 non-null  object
#  1   DATE OCC      230545 non-null  object
#  2   TIME OCC      230545 non-null  object
#  3   AREA          230545 non-null  int64
#  4   AREA NAME     230545 non-null  object
#  5   Part 1-2      230545 non-null  int64
#  6   Crm Cd        230545 non-null  int64
#  7   Crm Cd Desc   230545 non-null  object
#  8   Vict Age      230545 non-null  int64
#  9   Vict Sex      230545 non-null  object
#  10  Vict Descent  230545 non-null  object
#  11  Premis Desc   230545 non-null  object
#  12  Weapon Desc   230545 non-null  object
#  13  Status Desc   230545 non-null  object
#  14  LOCATION      230545 non-null  object
# dtypes: int64(4), object(11)
# memory usage: 26.4+ MB

# %%
# here the result tells that there are 230545 rows and 15 columns also tells names of each columns along with the data types.

# %%
# to know no. rows and columns
data.shape
# Out:
# (230545, 15)

# %%
# to know complete statistical data 
data.describe()
# Out:
#                 AREA       Part 1-2         Crm Cd       Vict Age
# count  230545.000000  230545.000000  230545.000000  230545.000000
# mean       10.466881       1.544991     508.044629      34.451513
# std         6.225582       0.497973     240.542475      18.003355
# min         1.000000       1.000000     110.000000      -2.000000
# 25%         5.000000       1.000000     230.000000      23.000000
# 50%        11.000000       2.000000     624.000000      33.000000
# 75%        16.000000       2.000000     626.000000      46.000000
# max        21.000000       2.000000     956.000000      99.000000

# %%
# areas in los angeles where crime happened.
data["AREA NAME"].value_counts()
# Out:
# AREA NAME
# 77th Street    20045
# Central        18206
# Southeast      15309
# Hollywood      14463
# Newton         14071
# Southwest      13926
# Rampart        13229
# Olympic        12325
# Pacific        10713
# Harbor          9386
# N Hollywood     9034
# Hollenbeck      8930
# West Valley     8741
# Mission         8621
# Wilshire        8484
# Topanga         7748
# Van Nuys        7665
# Northeast       7603
# West LA         7485
# Devonshire      7421
# Foothill        7140
# Name: count, dtype: int64

# %%
# therefore , we can say that in area "77th street " more crime happened.also, less in "foothill".

# %%
#gender
data["Vict Sex"].value_counts()
# Out:
# Vict Sex
# M    111540
# F    105368
# X     13618
# H        19
# Name: count, dtype: int64

# %%
# Weapons
data["Weapon Desc"].value_counts()
# Out:
# Weapon Desc
# STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)    123563
# UNKNOWN WEAPON/OTHER WEAPON                        24639
# VERBAL THREAT                                      16998
# HAND GUN                                           14710
# SEMI-AUTOMATIC PISTOL                               5198
#                                                    ...
# UZI SEMIAUTOMATIC ASSAULT RIFLE                        7
# ANTIQUE FIREARM                                        6
# M-14 SEMIAUTOMATIC ASSAULT RIFLE                       1
# HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE          1
# MAC-10 SEMIAUTOMATIC ASSAULT WEAPON                    1
# Name: count, Length: 77, dtype: int64

# %%
# Crm Cd Desc
data["Crm Cd Desc"].value_counts()
# Out:
# Crm Cd Desc
# BATTERY - SIMPLE ASSAULT                          53070
# ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT    38259
# INTIMATE PARTNER - SIMPLE ASSAULT                 32792
# ROBBERY                                           22846
# CRIMINAL THREATS - NO WEAPON DISPLAYED            13695
#                                                   ...
# COUNTERFEIT                                           1
# DRIVING WITHOUT OWNER CONSENT (DWOC)                  1
# CHILD ABANDONMENT                                     1
# TILL TAP - PETTY ($950 & UNDER)                       1
# DISHONEST EMPLOYEE - PETTY THEFT                      1
# Name: count, Length: 116, dtype: int64

# %%
data["Vict Age"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0          8
# 1          7
# 2         12
# 3          7
# 4         30
#           ..
# 230540    38
# 230541    23
# 230542    65
# 230543    35
# 230544    25
# Name: Vict Age, Length: 230545, dtype: int64>

# %%
#no. columns and they names
data.columns
# Out:
# Index(['Date Rptd', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME', 'Part 1-2',
#        'Crm Cd', 'Crm Cd Desc', 'Vict Age', 'Vict Sex', 'Vict Descent',
#        'Premis Desc', 'Weapon Desc', 'Status Desc', 'LOCATION'],
#       dtype='object')

# %%
# know duplicates
data.duplicated().value_counts()
# Out:
# False    229334
# True       1211
# Name: count, dtype: int64

# %%
#here,1211 are duplicated.

# %%
# remove duplicates
data.drop_duplicates(inplace = True)
data.duplicated().value_counts()
# Out:
# False    229334
# Name: count, dtype: int64

# %%
# harmed person age (lowest)
data["Vict Age"].min()
# Out:
# -2

# %%
# harmed person age (highest)
data["Vict Age"].max()
# Out:
# 99

# %%
#difference between data occ and data rptd
data = {
    'Date Rptd': ['2022-04-12', '2020-02-01', '2023-03-21', '2023-06-04', '2022-02-02'],
    'DATE OCC': ['2020-10-01', '2020-02-01', '2020-03-15', '2020-07-01', '2020-02-09']
}
df = pd.DataFrame(data)

df['Date Rptd'] = pd.to_datetime(df['Date Rptd'])
df['DATE OCC'] = pd.to_datetime(df['DATE OCC'])

df['date_difference'] = df['DATE OCC'] - df['Date Rptd']

print(df)
# Out:
#    Date Rptd   DATE OCC date_difference
# 0 2022-04-12 2020-10-01       -558 days
# 1 2020-02-01 2020-02-01          0 days
# 2 2023-03-21 2020-03-15      -1101 days
# 3 2023-06-04 2020-07-01      -1068 days
# 4 2022-02-02 2020-02-09       -724 days

# %%
data['Status Desc'].value_counts()
# Out:
# Status Desc
# Invest Cont     136954
# Adult Other      53802
# Adult Arrest     37180
# Juv Arrest        1669
# Juv Other          938
# UNK                  2
# Name: count, dtype: int64

# %%
minors_data = data[(data['Vict Age'] >= 10) & (data['Vict Age'] <= 19)]
print(minors_data)
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 2       2023-03-21  2020-03-15    12:00    19      Mission         2     812
# 10      2023-02-08  2020-09-01    12:00    15  N Hollywood         2     812
# 17      2022-01-15  2020-10-10    08:20    12  77th Street         1     820
# 18      2023-08-21  2020-01-01    15:30    13       Newton         2     812
# 19      2022-10-16  2020-07-01    18:00     5       Harbor         2     812
# ...            ...         ...      ...   ...          ...       ...     ...
# 230485  2023-02-17  2023-02-17    15:40    14      Pacific         2     624
# 230486  2023-08-19  2023-08-19    19:45    18    Southeast         2     930
# 230494  2023-04-27  2023-04-26    09:15    19      Mission         2     860
# 230507  2023-05-20  2023-05-20    18:20     3    Southwest         1     210
# 230532  2023-10-03  2023-10-03    02:40    10  West Valley         1     236
#
# ...

# %%
#To get a specific row
data[data.index == 2000]
# Out:
#        Date Rptd    DATE OCC TIME OCC  AREA   AREA NAME  Part 1-2  Crm Cd  \
# 2000  2021-10-12  2021-10-12    04:30     4  Hollenbeck         1     230
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 2000  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        38        M
#
#      Vict Descent Premis Desc                  Weapon Desc  Status Desc  \
# 2000            H  VACANT LOT  UNKNOWN WEAPON/OTHER WEAPON  Invest Cont
#
#                              LOCATION
# 2000  WHITTIER                     BL

# %%
#range 
data[data.index.isin(range(200,210))]
# Out:
#       Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 200  2022-03-09  2020-11-20    23:00     1      Central         2     626
# 201  2022-02-28  2020-12-07    18:00    16     Foothill         1     121
# 202  2021-11-08  2020-06-01    12:00    15  N Hollywood         2     860
# 203  2022-04-03  2020-10-01    00:01    20      Olympic         2     812
# 204  2022-02-24  2020-01-01    12:00     2      Rampart         2     812
# 205  2022-10-22  2020-10-22    21:45    12  77th Street         2     930
# 206  2021-01-26  2020-11-01    12:00    11    Northeast         2     860
# 207  2022-03-30  2020-03-30    12:00    11    Northeast         2     812
# 208  2022-03-19  2020-01-01    00:01    14      Pacific         1     815
# 209  2023-11-09  2020-11-09    14:00     8      West LA         2     624
#
#                                            Crm Cd Desc  Vict Age Vict Sex  \
# 200                  INTIMATE PARTNER - SIMPLE ASSAULT        22        F
# ...

# %%
# same as range 
data.iloc[300:320]
# Out:
#       Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 300  2022-12-20  2020-01-01    00:05    17   Devonshire         2     627
# 301  2022-02-18  2020-07-01    00:01     9     Van Nuys         1     121
# 302  2022-03-22  2020-05-05    18:00    21      Topanga         1     121
# 303  2022-05-24  2020-03-30    12:00    16     Foothill         1     815
# 304  2022-06-27  2020-06-16    22:00    19      Mission         1     121
# 305  2022-12-09  2020-03-06    10:45     4   Hollenbeck         2     624
# 306  2023-07-20  2020-07-01    18:00    21      Topanga         2     627
# 307  2022-02-18  2020-07-20    03:40     6    Hollywood         1     420
# 308  2023-04-10  2020-03-28    00:01     2      Rampart         1     310
# 309  2022-03-21  2020-09-18    12:00    12  77th Street         1     236
# 310  2022-11-14  2020-01-01    00:01    20      Olympic         2     812
# 311  2022-06-11  2020-06-11    02:10     8      West LA         1     310
# ...

# %%
data["AREA NAME"].value_counts()
# Out:
# AREA NAME
# 77th Street    20045
# Central        18206
# Southeast      15309
# Hollywood      14463
# Newton         14071
# Southwest      13926
# Rampart        13229
# Olympic        12325
# Pacific        10713
# Harbor          9386
# N Hollywood     9034
# Hollenbeck      8930
# West Valley     8741
# Mission         8621
# Wilshire        8484
# Topanga         7748
# Van Nuys        7665
# Northeast       7603
# West LA         7485
# Devonshire      7421
# Foothill        7140
# Name: count, dtype: int64

# %%
data.sort_values(by=["Crm Cd Desc"],ascending = True)
# Out:
#          Date Rptd    DATE OCC TIME OCC  AREA    AREA NAME  Part 1-2  Crm Cd  \
# 142880  2022-02-09  2022-02-09    19:30     7     Wilshire         1     648
# 154930  2023-09-18  2023-08-17    05:00    15  N Hollywood         1     648
# 141818  2022-09-19  2022-08-23    16:52     9     Van Nuys         1     648
# 183346  2023-04-24  2023-04-24    05:30     3    Southwest         1     648
# 30429   2021-02-23  2021-02-23    06:21    17   Devonshire         1     648
# ...            ...         ...      ...   ...          ...       ...     ...
# 64060   2021-06-15  2021-06-15    02:35     6    Hollywood         2     756
# 2790    2021-02-02  2021-02-02    09:30     5       Harbor         2     756
# 28275   2021-06-03  2021-06-01    23:00    16     Foothill         2     756
# 8969    2021-01-15  2021-01-15    01:58     1      Central         2     756
# 43007   2021-07-30  2021-07-30    20:45     2      Rampart         2     756
#
# ...

# %%
# vict age and vict sex

plt.figsize = (10,20)
sns.histplot(data ,y="Vict Age",x="Vict Sex")
# Out:
# <Axes: xlabel='Vict Sex', ylabel='Vict Age'>

# %%
plt.figsize=(50,30)

sns.relplot(data, x="DATE OCC", y="AREA NAME", kind="line")

# %%
plt.figsize=(100,100)

sns.pairplot(data)

# %%
plt.figsize=(100,100)
sns.histplot(data, x="Status Desc")
# Out:
# <Axes: xlabel='Status Desc', ylabel='Count'>

# %%
plt.figsize=(100,100)
sns.kdeplot(data, x="Crm Cd")
# Out:
# <Axes: xlabel='Crm Cd', ylabel='Density'>

# %%
plt.figsize=(100,100)
sns.displot(data, x="Vict Age", multiple="stack")

# %%
plt.figsize=(100,100)
sns.displot(data, x="AREA", multiple="stack", kind="kde")

# %%
data[["Date Rptd", "DATE OCC"]].head()
# Out:
#     Date Rptd    DATE OCC
# 0  2022-04-12  2020-10-01
# 1  2023-01-05  2020-02-01
# 2  2023-03-21  2020-03-15
# 3  2023-06-04  2020-07-01
# 4  2022-02-02  2020-02-09

# %%
#very first data recoreded
data["DATE OCC"].min()
# Out:
# '2020-01-01'

# %%
#last data recoreded
data["DATE OCC"].max()
# Out:
# '2023-12-31'

# %%
# Count the occurrences of different victim sexes
victim_sex_count = data['Vict Sex'].value_counts()

# Plot the distribution of victim sexes
plt.figure(figsize=(20, 8))
victim_sex_count.plot(kind='bar', color='green')
plt.title('Frequency Distribution of Victim Sex')
plt.xlabel('Sex')
plt.ylabel('Frequency')
plt.xticks(rotation=0)  # Keep the sex labels horizontal for better readability
plt.show()

# %%
# Calculate the frequency of each age group
# Plot the frequency distribution of victim age groups
plt.figure(figsize=(20, 6))
age_group.plot(kind='bar')
plt.title('Frequency Distribution of Victim Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Frequency')

plt.show()

# %%
plt.figure(figsize=(20, 5))

sns.countplot(data, x="AREA NAME", order=data["AREA NAME"].value_counts().index[::-1], palette="viridis_r")

plt.title('Crime Counts by Area')
plt.xlabel('Area Name')
plt.ylabel('Number of Crimes')


plt.show()
# Out:
# C:\Users\rvg59\AppData\Local\Temp\ipykernel_336\1061646810.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data, x="AREA NAME", order=data["AREA NAME"].value_counts().index[::-1], palette="viridis_r")

# %%
area_counts = data['AREA NAME'].value_counts()

plt.figure(figsize=(10, 10))  # Adjust the size as needed

# Create a pie chart
plt.pie(area_counts, labels=area_counts.index, autopct='%1.1f%%', startangle=140)

plt.title('Crime Counts by Area')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# # Conclusion
#
# ##### Targeted Law Enforcement:
# - Increasing police presence in high-crime areas, such as 77th Street, could help deter criminal activity. However, it's important to balance enforcement with community engagement to build trust.
#
# ##### Age-Specific Interventions:
# - Focusing on the 26-34 age group could involve targeted programs that address the underlying issues leading to crime, such as job training, education, and mental health support.
#
# ##### Control Measures:
# - Strengthening regulations around gun ownership could help reduce gun violence. This might include background checks, mandatory training for gun users, and restrictions on certain types of firearms.
#
# ##### Community Programs:
# - Investing in community outreach, youth programs, and mental health services can address root causes of crime and help divert individuals from criminal activity.
#
# ##### Data-Driven Strategies:
# - Analyzing crime data to identify trends and hot spots can help law enforcement allocate resources more effectively and implement preventive measures.
#
# A comprehensive strategy that includes these elements could lead to safer communities while ensuring that individual rights are respected
