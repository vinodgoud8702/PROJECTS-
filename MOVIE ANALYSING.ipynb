# %% [markdown]
# # ANALYSING MOVIE DATA

# %%
# libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# loading data 
data = pd.read_csv(r"C:\Users\rvg59\python project data\IMDb_Dataset.csv")

# %%
#to know is there any null 
data.isnull
# Out:
# <bound method DataFrame.isnull of                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 395                            Mother of the Bride          4.8  2024
# 396                        Beetlejuice Beetlejuice          7.1  2024
# 397                                The Idea of You          6.4  2024
# 398                                             IF          6.7  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# ...

# %%
#sum of nulls
data.isnull().sum()
# Out:
# Title                 0
# IMDb Rating           0
# Year                  0
# Certificates          0
# Genre                 0
# Director              0
# Star Cast             0
# MetaScore             0
# Duration (minutes)    0
# dtype: int64

# %%
# know duplicates
data.duplicated().value_counts()
# Out:
# False    255
# True     145
# Name: count, dtype: int64

# %%
# remove duplicates
data.drop_duplicates(inplace = True)
data.duplicated().value_counts()
# Out:
# False    255
# Name: count, dtype: int64

# %%
#top 5 
data.head()
# Out:
#                                            Title  IMDb Rating  Year  \
# 0                                      Gladiator          8.5  2000
# 1  Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2           Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                           Inglourious Basterds          8.4  2009
# 4                                    Borderlands          7.1  2024
#
#   Certificates      Genre               Director  \
# 0            R     Action           Ridley Scott
# 1        PG-13     Action  Christopher McQuarrie
# 2        PG-13     Action            Zack Snyder
# 3            R  Adventure      Quentin Tarantino
# 4            R     Action               Eli Roth
#
#                                    Star Cast  MetaScore  Duration (minutes)
# 0  David FranzoniJohn LoganWilliam Nicholson       67.0               155.0
# 1         Tom CruiseHayley AtwellVing Rhames       81.0               163.0
# ...

# %%
# last 5
data.tail()
# Out:
#                    Title  IMDb Rating  Year Certificates   Genre  \
# 391       Anyone But You          6.1  2023            R  Comedy
# 394    Kinds of Kindness          7.0  2024            R  Comedy
# 395  Mother of the Bride          4.8  2024        TV-PG  Comedy
# 397      The Idea of You          6.4  2024            R  Comedy
# 399         The Fall Guy          7.1  2024        PG-13  Action
#
#               Director                                     Star Cast  \
# 391         Will Gluck                       Ilana WolpertWill Gluck
# 394   Yorgos Lanthimos             Efthimis FilippouYorgos Lanthimos
# 395        Mark Waters  Brooke ShieldsMiranda CosgroveBenjamin Bratt
# 397  Michael Showalter     Anne HathawayNicholas GalitzineElla Rubin
# 399       David Leitch   Ryan GoslingEmily BluntAaron Taylor-Johnson
#
#      MetaScore  Duration (minutes)
# 391       52.0               103.0
# 394       72.0               164.0
# 395       39.0                88.0
# ...

# %%
#no. columns and they names
data.columns
# Out:
# Index(['Title', 'IMDb Rating', 'Year', 'Certificates', 'Genre', 'Director',
#        'Star Cast', 'MetaScore', 'Duration (minutes)'],
#       dtype='object')

# %%
# to know no. rows and columns
data.shape
# Out:
# (255, 9)

# %%
# to know complete statistical data 
data.describe()
# Out:
#        IMDb Rating         Year   MetaScore  Duration (minutes)
# count   255.000000   255.000000  255.000000          255.000000
# mean      7.173333  2014.207843   67.613333          117.953725
# std       0.952243    14.026126   15.050105           22.620083
# min       3.900000  1939.000000   26.000000           80.000000
# 25%       6.700000  2008.000000   59.000000          102.000000
# 50%       7.100000  2022.000000   67.000000          116.300000
# 75%       7.850000  2024.000000   78.000000          126.000000
# max       9.200000  2025.000000  100.000000          206.000000

# %%
#To get a specific row
data[data.index == 394]
# Out:
#                  Title  IMDb Rating  Year Certificates   Genre  \
# 394  Kinds of Kindness          7.0  2024            R  Comedy
#
#              Director                          Star Cast  MetaScore  \
# 394  Yorgos Lanthimos  Efthimis FilippouYorgos Lanthimos       72.0
#
#      Duration (minutes)
# 394               164.0

# %%
#range 
data[data.index.isin(range(200,210))]
# Out:
#                                          Title  IMDb Rating  Year  \
# 202                                 Deadpool 2          7.6  2018
# 203                          Avengers: Endgame          8.4  2019
# 205                    Ghostbusters: Afterlife          7.0  2021
# 207  Star Wars: Episode I - The Phantom Menace          6.5  1999
# 208                    Spider-Man: No Way Home          8.2  2021
# 209                               Ghostbusters          7.8  1984
#
#     Certificates      Genre       Director  \
# 202            R     Action   David Leitch
# 203        PG-13     Action  Anthony Russo
# 205        PG-13  Adventure  Jason Reitman
# 207           PG     Action   George Lucas
# 208        PG-13     Action      Jon Watts
# 209           PG     Action   Ivan Reitman
#
#                                      Star Cast  MetaScore  Duration (minutes)
# 202       Rhett ReesePaul WernickRyan Reynolds       66.0               119.0
# ...

# %%
# same as range 
data.iloc[29:39]
# Out:
#                              Title  IMDb Rating  Year Certificates      Genre  \
# 29                    Inside Out 2          7.1  2024           PG  Animation
# 30           Bad Boys: Ride or Die          7.1  2024            R     Action
# 31     Mad Max 2: The Road Warrior          7.6  1981            R     Action
# 32              Godzilla Minus One          7.9  2023        PG-13     Action
# 33              Love Lies Bleeding          6.7  2024            R     Action
# 34  Dawn of the Planet of the Apes          7.6  2014        PG-13     Action
# 35              Planet of the Apes          5.7  2001        PG-13     Action
# 36                         Mad Max          6.8  1979            R     Action
# 37  War for the Planet of the Apes          7.4  2017        PG-13     Action
# 38     Ghostbusters: Frozen Empire          6.2  2024        PG-13  Adventure
#
#             Director                                        Star Cast  \
# ...

# %%
data['Director'].value_counts()
# Out:
# Director
# George Miller        5
# Denis Villeneuve     5
# Tim Burton           5
# Martin Scorsese      5
# Quentin Tarantino    4
#                     ..
# Robert Lorenz        1
# Thea Sharrock        1
# Martin Brest         1
# Jonathan Demme       1
# Michael Showalter    1
# Name: count, Length: 199, dtype: int64

# %%
data['Genre'].value_counts()
# Out:
# Genre
# Action       79
# Animation    50
# Comedy       30
# Adventure    25
# Crime        23
# Horror       21
# Drama        19
# Fantasy       4
# Biography     3
# Thriller      1
# Name: count, dtype: int64

# %%
data['Certificates'].value_counts()
# Out:
# Certificates
# R            128
# PG-13         55
# PG            51
# G             11
# Not Rated      4
# TV-G           1
# Approved       1
# TV-MA          1
# NC-17          1
# 16+            1
# TV-PG          1
# Name: count, dtype: int64

# %%
data['Year'].value_counts()
# Out:
# Year
# 2024    79
# 2023    39
# 2022    13
# 2019     9
# 2018     7
# 2016     7
# 2001     6
# 2017     6
# 2021     6
# 1999     5
# 2004     5
# 2013     5
# 1995     4
# 2008     4
# 1994     4
# 2014     4
# 2007     4
# 2015     4
# 2005     3
# 2010     3
# 1984     3
# 1997     2
# 1979     2
# 1993     2
# 2009     2
# 2003     2
# 1985     2
# 2006     2
# 2011     2
# 2002     2
# 1990     1
# 1987     1
# 1939     1
# 2025     1
# 1971     1
# 1972     1
# 2000     1
# 1983     1
# 1991     1
# 1957     1
# 1976     1
# 1986     1
# 1981     1
# 1968     1
# 1996     1
# 2012     1
# 1988     1
# Name: count, dtype: int64

# %%
data['IMDb Rating'].value_counts()
# Out:
# IMDb Rating
# 7.1    31
# 7.0    17
# 7.6    12
# 7.2    11
# 8.0    10
# 7.4     9
# 7.5     9
# 6.7     9
# 8.2     9
# 7.3     8
# 6.5     8
# 6.8     8
# 8.4     8
# 7.8     7
# 7.7     7
# 7.9     7
# 8.6     6
# 8.5     6
# 8.1     6
# 6.2     5
# 6.3     5
# 6.1     5
# 5.7     4
# 6.9     4
# 5.0     4
# 5.5     4
# 6.4     4
# 5.6     4
# 8.3     3
# 6.0     3
# 8.7     3
# 5.2     2
# 9.0     2
# 5.9     2
# 5.8     2
# 8.9     2
# 8.8     1
# 3.9     1
# 9.2     1
# 4.6     1
# 6.6     1
# 5.3     1
# 4.9     1
# 4.4     1
# 4.8     1
# Name: count, dtype: int64

# %%
data.sort_values(by=["MetaScore"],ascending = False)
# Out:
#                                       Title  IMDb Rating  Year Certificates  \
# 137                           The Godfather          9.2  1972            R
# 106                            12 Angry Men          9.0  1957     Approved
# 58                                Toy Story          8.3  1995            G
# 75                              Ratatouille          8.1  2007            G
# 86                            Spirited Away          8.6  2001           PG
# ..                                      ...          ...   ...          ...
# 164                 Five Nights at Freddy's          5.5  2023        PG-13
# 11   Rebel Moon - Part One: A Child of Fire          5.6  2023        PG-13
# 41                       The Garfield Movie          5.9  2024           PG
# 271                     Garfield: The Movie          5.0  2004           PG
# 43                               Madame Web          3.9  2024        PG-13
#
#          Genre              Director  \
# ...

# %%
data['MetaScore'].max()
# Out:
# 100.0

# %%
data['MetaScore'].min()
# Out:
# 26.0

# %%
data['IMDb Rating'].max()
# Out:
# 9.2

# %%
data['IMDb Rating'].min()
# Out:
# 3.9

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 255 entries, 0 to 399
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Title               255 non-null    object
#  1   IMDb Rating         255 non-null    float64
#  2   Year                255 non-null    int64
#  3   Certificates        255 non-null    object
#  4   Genre               255 non-null    object
#  5   Director            255 non-null    object
#  6   Star Cast           255 non-null    object
#  7   MetaScore           255 non-null    float64
#  8   Duration (minutes)  255 non-null    float64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 19.9+ KB

# %%
data.drop_duplicates()
# Out:
#                                              Title  IMDb Rating  Year  \
# 0                                        Gladiator          8.5  2000
# 1    Mission: Impossible - Dead Reckoning Part One          7.7  2023
# 2             Rebel Moon - Part Two: The Scargiver          5.2  2024
# 3                             Inglourious Basterds          8.4  2009
# 4                                      Borderlands          7.1  2024
# ..                                             ...          ...   ...
# 391                                 Anyone But You          6.1  2023
# 394                              Kinds of Kindness          7.0  2024
# 395                            Mother of the Bride          4.8  2024
# 397                                The Idea of You          6.4  2024
# 399                                   The Fall Guy          7.1  2024
#
#     Certificates      Genre               Director  \
# 0              R     Action           Ridley Scott
# ...

# %%
data[["Title", "IMDb Rating"]].head()
# Out:
#                                            Title  IMDb Rating
# 0                                      Gladiator          8.5
# 1  Mission: Impossible - Dead Reckoning Part One          7.7
# 2           Rebel Moon - Part Two: The Scargiver          5.2
# 3                           Inglourious Basterds          8.4
# 4                                    Borderlands          7.1

# %%
data[["Title", "IMDb Rating"]].tail()
# Out:
#                    Title  IMDb Rating
# 391       Anyone But You          6.1
# 394    Kinds of Kindness          7.0
# 395  Mother of the Bride          4.8
# 397      The Idea of You          6.4
# 399         The Fall Guy          7.1

# %%
data[["Director", "Star Cast"]].head()
# Out:
#                 Director                                  Star Cast
# 0           Ridley Scott  David FranzoniJohn LoganWilliam Nicholson
# 1  Christopher McQuarrie         Tom CruiseHayley AtwellVing Rhames
# 2            Zack Snyder        Zack SnyderKurt JohnstadShay Hatten
# 3      Quentin Tarantino              Brad PittDiane KrugerEli Roth
# 4               Eli Roth                        Eli RothJoe Crombie

# %%
data[["Director", "Star Cast"]].tail()
# Out:
#               Director                                     Star Cast
# 391         Will Gluck                       Ilana WolpertWill Gluck
# 394   Yorgos Lanthimos             Efthimis FilippouYorgos Lanthimos
# 395        Mark Waters  Brooke ShieldsMiranda CosgroveBenjamin Bratt
# 397  Michael Showalter     Anne HathawayNicholas GalitzineElla Rubin
# 399       David Leitch   Ryan GoslingEmily BluntAaron Taylor-Johnson

# %%
data.shape[0]
# Out:
# 400

# %%
# average imda rating
data['IMDb Rating'].mean()
# Out:
# 7.11025

# %%
#top 10 hit movies using rating
# Top 10 rated movies     #sorting
top_rated = data.sort_values(by='IMDb Rating', ascending=False).head(10)
print("Top Rated Movies:\n", top_rated[['Title', 'IMDb Rating']])
# Out:
# Top Rated Movies:
#                                                   Title  IMDb Rating
# 137                                      The Godfather          9.2
# 130                                    The Dark Knight          9.0
# 106                                       12 Angry Men          9.0
# 15   The Lord of the Rings: The Fellowship of the Ring          8.9
# 132                                       Pulp Fiction          8.9
# 14                                           Inception          8.8
# 221                                          Inception          8.8
# 24                                        Interstellar          8.7
# 125                                         Goodfellas          8.7
# 225                                       Interstellar          8.7

# %%
#top 10 flop movies using rating
# Top 10 rated movies     #sorting
flop = data.sort_values(by='IMDb Rating', ascending=True).head(10)
print("flop Movies:\n", flop[['Title', 'IMDb Rating']])
# Out:
# flop Movies:
#                       Title  IMDb Rating
# 243             Madame Web          3.9
# 43              Madame Web          3.9
# 345             Madame Web          3.9
# 302  You Can't Run Forever          4.4
# 150                Monster          4.6
# 395    Mother of the Bride          4.8
# 189                  Tarot          4.9
# 157         A Serbian Film          5.0
# 361            Seize Them!          5.0
# 271    Garfield: The Movie          5.0

# %%
plt.figure(figsize=(15, 10))


sns.scatterplot(data, x='Year', y='IMDb Rating')
plt.title('imdb and year')
plt.xlabel('Year')
plt.ylabel('IMDb Rating')
# Out:
# Text(0, 0.5, 'IMDb Rating')

# %%
sns.boxplot(data=data, x='Certificates', y='IMDb Rating')
plt.title('IMDb Ratings and Certificates')
plt.xlabel('Certificates')
plt.ylabel('IMDb Rating')
# Out:
# Text(0, 0.5, 'IMDb Rating')

# %%
sns.boxplot(data=data, x='Genre', y='IMDb Rating')
plt.title('IMDb Ratings and Genre')
plt.xlabel('Genre')
plt.ylabel('IMDb Rating')
# Out:
# Text(0, 0.5, 'IMDb Rating')

# %%
sns.scatterplot(data=data, x='MetaScore', y='IMDb Rating')
plt.title('IMDb Ratings and MetaScore')
plt.xlabel('MetaScore')
plt.ylabel('IMDb Rating')
# Out:
# Text(0, 0.5, 'IMDb Rating')

# %%
sns.scatterplot(data=data, x='Duration (minutes)', y='IMDb Rating')
plt.title('IMDb Ratings and Duration (minutes)')
plt.xlabel('Duration (minutes)')
plt.ylabel('IMDb Rating')
# Out:
# Text(0, 0.5, 'IMDb Rating')

# %%
sns.histplot(data['IMDb Rating'])
plt.title('Distribution of IMDb Ratings')
plt.xlabel('IMDb Rating')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
sns.pairplot(data[numerical_cols])
plt.show()

# %%
area_counts = data['MetaScore'].value_counts()

plt.figure(figsize=(20,25))  # Adjust the size as needed

# Create a pie chart
plt.pie(area_counts, labels=area_counts.index, autopct='%1.1f%%', startangle=140)

plt.title('metascore')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
